# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
import xml.etree.ElementTree as ET

# %%
df = pd.read_xml("kanjidic2.xml")

df
# Out:
#        file_version database_version date_of_creation literal  codepoint  \
# 0               4.0         2021-220       2021-08-08    None        NaN
# 1               NaN             None             None       亜        NaN
# 2               NaN             None             None       唖        NaN
# 3               NaN             None             None       娃        NaN
# 4               NaN             None             None       阿        NaN
# ...             ...              ...              ...     ...        ...
# 13104           NaN             None             None       辶        NaN
# 13105           NaN             None             None       逸        NaN
# 13106           NaN             None             None       難        NaN
# 13107           NaN             None             None       響        NaN
# 13108           NaN             None             None       頻        NaN
#
#        radical  misc  dic_number  query_code  reading_meaning
# ...

# %%
#output empty nodes
df.head(50)
# Out:
#     file_version database_version date_of_creation literal  codepoint  \
# 0            4.0         2021-220       2021-08-08    None        NaN
# 1            NaN             None             None       亜        NaN
# 2            NaN             None             None       唖        NaN
# 3            NaN             None             None       娃        NaN
# 4            NaN             None             None       阿        NaN
# 5            NaN             None             None       哀        NaN
# 6            NaN             None             None       愛        NaN
# 7            NaN             None             None       挨        NaN
# 8            NaN             None             None       姶        NaN
# 9            NaN             None             None       逢        NaN
# 10           NaN             None             None       葵        NaN
# 11           NaN             None             None       茜        NaN
# ...

# %%
#with open("kanjidic.json", "wt", encoding="utf-8") as fp:
#    json.dump(kanji, fp, ensure_ascii=False, indent=4)

# %%
with open('kanjidic.json',encoding="utf-8") as f:
    data = json.load(f)

# Output: {'name': 'Bob', 'languages': ['English', 'Fench']}
print(data)

# %%
df2 = pd.read_xml(r"kanjidic2.xml", xpath="./character")

# %%
df2.iloc[0]
# Out:
# literal              亜
# codepoint          NaN
# radical            NaN
# misc               NaN
# dic_number         NaN
# query_code         NaN
# reading_meaning    NaN
# Name: 0, dtype: object

# %%
#exploring XML tree

# %%
import xml.etree.ElementTree as ET
mytree = ET.parse('kanjidic2.xml')
myroot = mytree.getroot()

# %%
mytree.findall('character')
# Out:
# [<Element 'character' at 0x0000023926BF99A8>,
#  <Element 'character' at 0x0000023926749B88>,
#  <Element 'character' at 0x000002392674CEF8>,
#  <Element 'character' at 0x00000239267523B8>,
#  <Element 'character' at 0x0000023926758AE8>,
#  <Element 'character' at 0x00000239267614F8>,
#  <Element 'character' at 0x0000023925F20278>,
#  <Element 'character' at 0x0000023925F3E958>,
#  <Element 'character' at 0x0000023925F55458>,
#  <Element 'character' at 0x0000023925F7C278>,
#  <Element 'character' at 0x0000023925F99D18>,
#  <Element 'character' at 0x0000023925FBA818>,
#  <Element 'character' at 0x0000023925FD2BD8>,
#  <Element 'character' at 0x000002392601CDB8>,
#  <Element 'character' at 0x000002392604EF98>,
#  <Element 'character' at 0x00000239260783B8>,
#  <Element 'character' at 0x0000023926099DB8>,
#  <Element 'character' at 0x00000239260BC778>,
#  <Element 'character' at 0x00000239260DD8B8>,
#  <Element 'character' at 0x00000239260F49F8>,
# ...

# %%
#here are 13108 entries
len(mytree.findall('character'))
# Out:
# 13108

# %%
for x in mytree.findall('character'):
    radical = x.find('radical')
    print(radical.attrib)
#mytree.find('character')
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# ...

# %%
for x in mytree.findall('character/radical'):
     print(x.tag, x.attrib)
#mytree.find('character')
# Out:
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# radical {}
# ...

# %%
for x in myroot:
     print(x.tag, x.attrib)
#mytree.find('character')
# Out:
# header {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# character {}
# ...

# %%
myroot.tag
# Out:
# 'kanjidic2'

# %%
myroot.attrib
# Out:
# {}

# %%
print(myroot[0].tag)
print(myroot[1].tag)
print(myroot[3].tag)
# Out:
# header
# character
# character

# %%
for x in myroot[1]:
     print(x.tag, x.attrib)
# Out:
# literal {}
# codepoint {}
# radical {}
# misc {}
# dic_number {}
# query_code {}
# reading_meaning {}

# %%
#all entries aside from literal are empty
for x in myroot[1]:
    print(x.text)
    for y in myroot[x].attrib:
        print(y)
# Out:
# 亜
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-5694f7a08644> in <module>
#       2 for x in myroot[1]:
#       3     print(x.text)
# ----> 4     for y in myroot[x].attrib:
#       5         print(y)
#
# TypeError: element indices must be integers

# %%
dico = {}

for x in myroot.findall('character'):
    print(x.find('literal').tag, ":", x.find('literal').text)
# Out:
# literal : 亜
# literal : 唖
# literal : 娃
# literal : 阿
# literal : 哀
# literal : 愛
# literal : 挨
# literal : 姶
# literal : 逢
# literal : 葵
# literal : 茜
# literal : 穐
# literal : 悪
# literal : 握
# literal : 渥
# literal : 旭
# literal : 葦
# literal : 芦
# literal : 鯵
# literal : 梓
# literal : 圧
# literal : 斡
# literal : 扱
# literal : 宛
# literal : 姐
# literal : 虻
# literal : 飴
# literal : 絢
# literal : 綾
# literal : 鮎
# literal : 或
# literal : 粟
# literal : 袷
# literal : 安
# literal : 庵
# literal : 按
# literal : 暗
# literal : 案
# literal : 闇
# literal : 鞍
# literal : 杏
# literal : 以
# literal : 伊
# literal : 位
# literal : 依
# literal : 偉
# literal : 囲
# literal : 夷
# literal : 委
# literal : 威
# literal : 尉
# literal : 惟
# literal : 意
# literal : 慰
# literal : 易
# literal : 椅
# literal : 為
# literal : 畏
# literal : 異
# literal : 移
# literal : 維
# literal : 緯
# literal : 胃
# literal : 萎
# literal : 衣
# literal : 謂
# literal : 違
# literal : 遺
# literal : 医
# literal : 井
# literal : 亥
# ...

# %%
dico = {}

for x in myroot.findall('character'):
    dico['literal']                = x.find('literal').text
    dico["radical"]             = x.find('radical/rad_value').text
    dico["stroke_count"]        = x.find('misc/stroke_count').text
#    dico["jap_reading_meaning"] = x.find('reading_meaning/rmgroup/reading').text
#    dico["cn_reading_meaning"]  = x.find('reading_meaning/rmgroup/reading').text

print(dico)
# Out:
# {'literal': '頻', 'radical': '181', 'stroke_count': '16'}

# %%
dico = []

for x in myroot.findall('character'):
    item                = x.find('literal').text
    item2                = x.find('literal').tag
    grade2               = x.find('codepoint/cp_value').tag
    grade               = x.find('codepoint/cp_value').text
    radical             = x.find('radical/rad_value').text
    radical2             = x.find('radical/rad_value').tag
    stroke_count        = x.find('misc/stroke_count').text
    jap_reading_meaning = x.find('reading_meaning/rmgroup/reading').text
    cn_reading_meaning  = x.find('reading_meaning/rmgroup/reading').text
    
    dico.append(item)
    dico.append(grade)
    dico.append(radical)
    print(item2, ":",item,  grade2, ":",grade, radical2, ":", radical, stroke_count)
# Out:
# literal : 亜 cp_value : 4e9c rad_value : 7 7
# literal : 唖 cp_value : 5516 rad_value : 30 10
# literal : 娃 cp_value : 5a03 rad_value : 38 9
# literal : 阿 cp_value : 963f rad_value : 170 8
# literal : 哀 cp_value : 54c0 rad_value : 30 9
# literal : 愛 cp_value : 611b rad_value : 61 13
# literal : 挨 cp_value : 6328 rad_value : 64 10
# literal : 姶 cp_value : 59f6 rad_value : 38 9
# literal : 逢 cp_value : 9022 rad_value : 162 10
# literal : 葵 cp_value : 8475 rad_value : 140 12
# literal : 茜 cp_value : 831c rad_value : 140 9
# literal : 穐 cp_value : 7a50 rad_value : 115 16
# literal : 悪 cp_value : 60aa rad_value : 61 11
# literal : 握 cp_value : 63e1 rad_value : 64 12
# literal : 渥 cp_value : 6e25 rad_value : 85 12
# literal : 旭 cp_value : 65ed rad_value : 72 6
# literal : 葦 cp_value : 8466 rad_value : 140 13
# literal : 芦 cp_value : 82a6 rad_value : 140 7
# literal : 鯵 cp_value : 9bf5 rad_value : 195 19
# literal : 梓 cp_value : 6893 rad_value : 75 11
# ...

# %%
print(dico)
# Out:
# ['亜', '4e9c', '7', '唖', '5516', '30', '娃', '5a03', '38', '阿', '963f', '170', '哀', '54c0', '30', '愛', '611b', '61', '挨', '6328', '64', '姶', '59f6', '38', '逢', '9022', '162', '葵', '8475', '140', '茜', '831c', '140', '穐', '7a50', '115', '悪', '60aa', '61', '握', '63e1', '64', '渥', '6e25', '85', '旭', '65ed', '72', '葦', '8466', '140', '芦', '82a6', '140', '鯵', '9bf5', '195', '梓', '6893', '75', '圧', '5727', '32', '斡', '65a1', '68', '扱', '6271', '64', '宛', '5b9b', '40', '姐', '59d0', '38', '虻', '867b', '142', '飴', '98f4', '184', '絢', '7d62', '120', '綾', '7dbe', '120', '鮎', '9b8e', '195', '或', '6216', '62', '粟', '7c9f', '119', '袷', '88b7', '145', '安', '5b89', '40', '庵', '5eb5', '53', '按', '6309', '64', '暗', '6697', '72', '案', '6848', '75', '闇', '95c7', '169', '鞍', '978d', '177', '杏', '674f', '75', '以', '4ee5', '9', '伊', '4f0a', '9', '位', '4f4d', '9', '依', '4f9d', '9', '偉', '5049', '9', '囲', '56f2', '31', '夷', '5937', '37', '委', '59d4', '38', '威', '5a01', '38', '尉', '5c09', '41', '惟', '60df', '61'
# ...

# %%
dico = []

for x in myroot.findall('character'):
    item                = x.find('literal').text
    grade               = x.find('codepoint/cp_value').text
    radical             = x.find('radical/rad_value').text
    stroke_count        = x.find('misc/stroke_count').text
    jap_reading_meaning = x.find('reading_meaning/rmgroup/reading').text
    cn_reading_meaning  = x.find('reading_meaning/rmgroup/reading').text
    
    dico.append(item)
    dico.append(grade)
    dico.append(radical)
    print(item, grade, radical, stroke_count)
# Out:
# 亜 4e9c 7 7
# 唖 5516 30 10
# 娃 5a03 38 9
# 阿 963f 170 8
# 哀 54c0 30 9
# 愛 611b 61 13
# 挨 6328 64 10
# 姶 59f6 38 9
# 逢 9022 162 10
# 葵 8475 140 12
# 茜 831c 140 9
# 穐 7a50 115 16
# 悪 60aa 61 11
# 握 63e1 64 12
# 渥 6e25 85 12
# 旭 65ed 72 6
# 葦 8466 140 13
# 芦 82a6 140 7
# 鯵 9bf5 195 19
# 梓 6893 75 11
# 圧 5727 32 5
# 斡 65a1 68 14
# 扱 6271 64 6
# 宛 5b9b 40 8
# 姐 59d0 38 8
# 虻 867b 142 9
# 飴 98f4 184 13
# 絢 7d62 120 12
# 綾 7dbe 120 14
# 鮎 9b8e 195 16
# 或 6216 62 8
# 粟 7c9f 119 12
# 袷 88b7 145 11
# 安 5b89 40 6
# 庵 5eb5 53 11
# 按 6309 64 9
# 暗 6697 72 13
# 案 6848 75 10
# 闇 95c7 169 17
# 鞍 978d 177 15
# 杏 674f 75 7
# 以 4ee5 9 5
# 伊 4f0a 9 6
# 位 4f4d 9 7
# 依 4f9d 9 8
# 偉 5049 9 12
# 囲 56f2 31 7
# 夷 5937 37 6
# 委 59d4 38 8
# 威 5a01 38 9
# 尉 5c09 41 11
# 惟 60df 61 11
# 意 610f 61 13
# 慰 6170 61 15
# 易 6613 72 8
# 椅 6905 75 12
# 為 70ba 86 9
# 畏 754f 102 9
# 異 7570 102 11
# 移 79fb 115 11
# 維 7dad 120 14
# 緯 7def 120 16
# 胃 80c3 130 9
# 萎 840e 140 11
# 衣 8863 145 6
# 謂 8b02 149 16
# 違 9055 162 13
# ...

# %%
import lxml.etree as et
tree = et.parse('kanjidic2.xml')
for elt in tree.xpath("//character"):
    elt.getparent().remove(elt)
    print(elt.getparent().remove(elt))

# %%
radi = myroot.find('./character/radical')

for c in radi :
    print(c.attrib)
    print(c.text)

# %%
radi = myroot.find('./character/misc/strokecount')

for c in radi :
    print(c.attrib)
    print(c.text)

# %%
radi = myroot.find('./character/radical')

for c in radi :
    print(c.text)

# %%
for child in myroot.find(tree):
    print(x.tag, x.attrib)

# %%
df2 = pd.read_xml("E:\Data_projekts\kanji_proyecto\kanjidic2.xml", 
xpath='//character', encoding='utf-8')

df2.head

# %%
df2['dic_number'][1]

# %%
df2.info()

# %%
df3 = pd.read_xml("kanjidic2.xml", 
xpath='./character', encoding='utf-8')

df3.head

# %%
from lxml import etree

doc = etree.parse('kanjidic2.xml')
doc.xpath('(//reading[@r_type="ja_kun"] | //meaning[2] | //nanori)')
arr = doc.xpath('(//reading[@r_type="ja_kun"] | //meaning[2] | //nanori)')

for e in arr:
    print(e.text)

# %%
elec_texts = tree.findall('character')  
for elec_text in elec_texts:                            
     print(elec_text.text)

# %%
for node in myroot.find('./character'):
    radical = node.attrib.get('Radical')
    print(radical)

# %%
import urllib2
tree =ET.parse(urllib2.urlopen('kanjidic2.xml'))
root = tree.getroot()
for child in root.iter():
   print(child.tag, child.attrib)

# %%
dico[1:10]

# %%
myroot2 = ET.fromstring('kanjidic2.xml')
#print(myroot)
print(myroot2.tag)

# %%
  
import gzip
import json
import requests
import string
import xml.etree.ElementTree as etree

# Converts the KANJIDIC dictionary in xml.gz format into JSON discarding unneeded data
# The data is downloaded by the script from the official KANJIDIC project website
# Outputs kanjidic.json with stroke, grade, freq, jlpt, meanings and readings for every kanji

kanji = {}

def get_kanjidic_data():

    url = "http://www.edrdg.org/kanjidic/kanjidic2.xml.gz"
    request = requests.get(url)
    data = gzip.decompress(request.content)
    xml = data.decode("utf-8")
    tree = etree.fromstring(xml)

    # Source: https://github.com/olsgaard/Japanese_nlp_scripts/blob/master/hiragana_katakana_translitteration.py
    katakana_chart = "ァアィイゥウェエォオカガキギクグケゲコゴサザシジスズセゼソゾタダチヂッツヅテデトドナニヌネノハバパヒビピフブプヘベペホボポマミムメモャヤュユョヨラリルレロヮワヰヱヲンヴヵヶヽヾ"
    hiragana_chart = "ぁあぃいぅうぇえぉおかがきぎくぐけげこごさざしじすずせぜそぞただちぢっつづてでとどなにぬねのはばぱひびぴふぶぷへべぺほぼぽまみむめもゃやゅゆょよらりるれろゎわゐゑをんゔゕゖゝゞ"
    kat2hir = str.maketrans(katakana_chart, hiragana_chart)

    for character in tree.iter("character"):
        entry = {
            "strokes": None,
            "grade": None,
            "freq": None,
            "jlpt": None,
            "meanings": [],
            "readings_on": [],
            "readings_kun": []
        }

        literal = character.find("literal").text
        kanji[literal] = entry

        misc = character.find("misc")
        if misc is not None:
            grade = misc.find("grade")
            if grade is not None:
                entry["grade"] = int(grade.text)
            freq = misc.find("freq")
            if freq is not None:
                entry["freq"] = int(freq.text)
            jlpt = misc.find("jlpt")
            if jlpt is not None:
                entry["jlpt"] = int(jlpt.text)
            stroke_count = misc.find("stroke_count")
            if stroke_count is not None:
                entry["strokes"] = int(stroke_count.text)
        
        reading_meaning = character.find("reading_meaning")
        if reading_meaning is not None:
            rmgroups = reading_meaning.findall("rmgroup")
            for rmgroup in rmgroups:
                
                meanings = rmgroup.findall("meaning")
                for meaning in meanings:
                    m_lang = meaning.get("m_lang")
                    if m_lang is None or m_lang == "en":
                        entry["meanings"].append(string.capwords(meaning.text))
                
                readings = rmgroup.findall("reading")
                for reading in readings:
                    r_type = reading.get("r_type")
                    if r_type == "ja_on":
                        entry["readings_on"].append(reading.text.translate(kat2hir))
                    elif r_type == "ja_kun":
                        entry["readings_kun"].append(reading.text)                    

get_kanjidic_data()

with open("kanjidic.json", "wt", encoding="utf-8") as fp:
    json.dump(kanji, fp, ensure_ascii=False, indent=4)
