# %%
import pandas as pd

# %%
#fetch Kanji Kangxi dictionary id_number (colonnne "No.")
df_radicals = pd.read_html('https://en.wikipedia.org/wiki/List_of_kanji_radicals_by_stroke_count')[0]

df_radicals
# Out:
#      No. Radical (variants)  Stroke count  \
# 0      1                  一             1
# 1      2                  丨             1
# 2      3                  丶             1
# 3      4                  丿             1
# 4      5              乙 (乚)             1
# ..   ...                ...           ...
# 209  210                  齊            14
# 210  211              歯 (齒)            12
# 211  212              竜 (龍)            10
# 212  213              亀 (龜)            11
# 213  214                  龠            17
#
#                          Meaning and reading  Frequency  Jōyō freq Examples  \
# 0                          one (いち, ichi, 一)       42.0       50.0   七三丈不丘世
# 1                    line, stick (ぼう, bō, 棒)       21.0        NaN        中
# 2                           dot (てん, ten, 点)       10.0        NaN       丸主
# 3    bend, possessive particle no (の, no, ノ)       33.0        NaN      久之乎
# 4               second, latter (おつ, otsu, 乙)       42.0        NaN       九也
# ..                                       ...        ...        ...      ...
# 209             even, uniformly (せい, sei, 斉)       18.0        NaN    齋 齏 齏
# 210                     tooth, molar (は, ha)      162.0        NaN    齡 齠 齗
# 211                        dragon (りゅう, ryū)       14.0        NaN      龖 龘
# 212              turtle, tortoise (かめ, kame)       24.0        NaN        龝
# 213                         flute (やく, yaku)       19.0        NaN        龣
#
#     Group
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 209   NaN
# 210   NaN
# 211   NaN
# 212   NaN
# 213   NaN
#
# [214 rows x 8 columns]

# %%
#in this df_radicals, Meaning & Reading are concatenated into the same column "Meaning and reading"
#fetch other Kanji list, which lacks of need "No." column, but has tidy differentiated "meaning" & "reading" columns
# -> dfs to be merged
df_meaning_tidy = pd.read_html('https://en.wikipedia.org/wiki/List_of_kanji_radicals_by_frequency')[2]

df_meaning_tidy
# Out:
#     Radical  Stroke count Hiragana-Romaji         Meaning Position  \
# 0         一             1         いち-ichi             one      NaN
# 1         丨             1             NaN            line      NaN
# 2         丶             1          てん-ten             dot      NaN
# 3         丿             1             NaN            bend      NaN
# 4     乙 (乚)             1         おつ-otsu  second, latter      NaN
# ..      ...           ...             ...             ...      ...
# 188       品             9          ひん-hin            item      NaN
# 189       馬            10          うま-uma           horse      NaN
# 190       高            10       たかい-takai      tall, high      NaN
# 191       啇            11             NaN      base, stem      NaN
# 192       無            12            む-mu         nothing      NaN
#
#                   Examples
# 0                    一 戸 旦
# 1                巾 引 中 甲 旧
# 2            刃 凡 丸 丹 太 犬 丼
# 3              丈 久 才 万 丹 少
# 4    乙 乞 乏 孔 屯 札 礼 宅 乱 枕 乳
# ..                     ...
# 188                    NaN
# 189                    NaN
# 190                    NaN
# 191              嫡 滴 摘 適 敵
# 192                    無 舞
#
# [193 rows x 6 columns]

# %%
df_merged = df_radicals.merge(df_meaning_tidy,
                             how='left',
                             left_on="Radical (variants)",
                             right_on="Radical")

df_merged
# Out:
#      No. Radical (variants)  Stroke count_x  \
# 0      1                  一               1
# 1      2                  丨               1
# 2      3                  丶               1
# 3      4                  丿               1
# 4      5              乙 (乚)               1
# ..   ...                ...             ...
# 209  210                  齊              14
# 210  211              歯 (齒)              12
# 211  212              竜 (龍)              10
# 212  213              亀 (龜)              11
# 213  214                  龠              17
#
#                          Meaning and reading  Frequency  Jōyō freq Examples_x  \
# 0                          one (いち, ichi, 一)       42.0       50.0     七三丈不丘世
# 1                    line, stick (ぼう, bō, 棒)       21.0        NaN          中
# 2                           dot (てん, ten, 点)       10.0        NaN         丸主
# 3    bend, possessive particle no (の, no, ノ)       33.0        NaN        久之乎
# 4               second, latter (おつ, otsu, 乙)       42.0        NaN         九也
# ..                                       ...        ...        ...        ...
# 209             even, uniformly (せい, sei, 斉)       18.0        NaN      齋 齏 齏
# 210                     tooth, molar (は, ha)      162.0        NaN      齡 齠 齗
# 211                        dragon (りゅう, ryū)       14.0        NaN        龖 龘
# 212              turtle, tortoise (かめ, kame)       24.0        NaN          龝
# 213                         flute (やく, yaku)       19.0        NaN          龣
#
#     Group Radical  Stroke count_y Hiragana-Romaji         Meaning Position  \
# 0     NaN       一             1.0         いち-ichi             one      NaN
# 1     NaN       丨             1.0             NaN            line      NaN
# 2     NaN       丶             1.0          てん-ten             dot      NaN
# 3     NaN       丿             1.0             NaN            bend      NaN
# 4     NaN   乙 (乚)             1.0         おつ-otsu  second, latter      NaN
# ..    ...     ...             ...             ...             ...      ...
# 209   NaN     NaN             NaN             NaN             NaN      NaN
# 210   NaN     NaN             NaN             NaN             NaN      NaN
# 211   NaN     NaN             NaN             NaN             NaN      NaN
# 212   NaN     NaN             NaN             NaN             NaN      NaN
# 213   NaN     NaN             NaN             NaN             NaN      NaN
#
#                 Examples_y
# 0                    一 戸 旦
# 1                巾 引 中 甲 旧
# 2            刃 凡 丸 丹 太 犬 丼
# 3              丈 久 才 万 丹 少
# 4    乙 乞 乏 孔 屯 札 礼 宅 乱 枕 乳
# ..                     ...
# 209                    NaN
# 210                    NaN
# 211                    NaN
# 212                    NaN
# 213                    NaN
#
# [214 rows x 14 columns]

# %%
#merged 109 rows - remain 105 rows where merged failed - unmatched join key 
#- "Radical (variants)" has many concatenated radicals between parenthesis - to be wrangled
df_merged.loc[df_merged["Radical"].isnull()]
# Out:
#      No. Radical (variants)  Stroke count_x  \
# 8      9            人 (亻,𠆢)               2
# 10    11              入 (𠆢)               2
# 11    12              八 (ハ)               2
# 17    18            刀 (刂,⺈)               2
# 22    23              亡 (匸)               3
# ..   ...                ...             ...
# 209  210                  齊              14
# 210  211              歯 (齒)              12
# 211  212              竜 (龍)              10
# 212  213              亀 (龜)              11
# 213  214                  龠              17
#
#                                Meaning and reading  Frequency  Jōyō freq  \
# 8                              human (ひと, hito, 人)      794.0       83.0
# 10                              enter (いる, iru, 入)       28.0        NaN
# 11     eight, eight-head (はちがしら, hachigashira, 八頭)       44.0        NaN
# 17                          sword (かたな, katana, 刀)      377.0       37.0
# 22   dead, hiding frame (かくしがまえ, kakushigamae, 隠構)       17.0        NaN
# ..                                             ...        ...        ...
# 209                   even, uniformly (せい, sei, 斉)       18.0        NaN
# 210                           tooth, molar (は, ha)      162.0        NaN
# 211                              dragon (りゅう, ryū)       14.0        NaN
# 212                    turtle, tortoise (かめ, kame)       24.0        NaN
# 213                               flute (やく, yaku)       19.0        NaN
#
#             Examples_x    Group Radical  Stroke count_y Hiragana-Romaji  \
# 8                 仁休位今  Top 25%     NaN             NaN             NaN
# 10                 入全兩      NaN     NaN             NaN             NaN
# 11                公六共兵      NaN     NaN             NaN             NaN
# 17            刀分切初利刻則前  Top 75%     NaN             NaN             NaN
# 22   亡 妄 忙 忘 盲 荒 望 慌 網      NaN     NaN             NaN             NaN
# ..                 ...      ...     ...             ...             ...
# 209              齋 齏 齏      NaN     NaN             NaN             NaN
# 210              齡 齠 齗      NaN     NaN             NaN             NaN
# 211                龖 龘      NaN     NaN             NaN             NaN
# 212                  龝      NaN     NaN             NaN             NaN
# 213                  龣      NaN     NaN             NaN             NaN
#
#     Meaning Position Examples_y
# 8       NaN      NaN        NaN
# 10      NaN      NaN        NaN
# 11      NaN      NaN        NaN
# 17      NaN      NaN        NaN
# 22      NaN      NaN        NaN
# ..      ...      ...        ...
# 209     NaN      NaN        NaN
# 210     NaN      NaN        NaN
# 211     NaN      NaN        NaN
# 212     NaN      NaN        NaN
# 213     NaN      NaN        NaN
#
# [105 rows x 14 columns]

# %%
df_meaning_tidy['Radical'].tail(50)
# Out:
# 143        缶
# 144        羊
# 145        羽
# 146        耳
# 147        自
# 148        至
# 149        舌
# 150        舟
# 151    艮 (良)
# 152        虍
# 153        虫
# 154        血
# 155        行
# 156        衣
# 157    覀 (襾)
# 158        臣
# 159        見
# 160        角
# 161        言
# 162        谷
# 163        豆
# 164        豕
# 165        貝
# 166        足
# 167        身
# 168        車
# 169        辛
# 170        辰
# 171        酉
# 172        里
# 173        赤
# 174        走
# 175        金
# 176        長
# 177        門
# 178        隹
# 179        雨
# 180        青
# 181        岡
# 182        免
# 183        斉
# 184        音
# 185        頁
# 186        食
# 187        首
# 188        品
# 189        馬
# 190        高
# 191        啇
# 192        無
# Name: Radical, dtype: object

# %%
df_meaning_tidy['Radical'] = df_meaning_tidy['Radical'].str.replace(' ', ',')

df_meaning_tidy['Radical_split'] = df_meaning_tidy['Radical'].str.split(",")


#df_meaning_tidy['Radical_split'] = df_meaning_tidy['Radical_split'].apply(lambda x : list(x))
#df_meaning_tidy['Radical_split'] = df_meaning_tidy['Radical_split'].

df_meaning_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Radical          193 non-null    object
#  1   Stroke count     193 non-null    int64
#  2   Hiragana-Romaji  132 non-null    object
#  3   Meaning          189 non-null    object
#  4   Position         38 non-null     object
#  5   Examples         133 non-null    object
#  6   Radical_split    193 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 10.7+ KB

# %%
df_meaning_tidy.isnull().sum()
# Out:
# Radical              0
# Stroke count         0
# Hiragana-Romaji     61
# Meaning              4
# Position           155
# Examples            60
# Radical_split        0
# dtype: int64

# %%
df_meaning_tidy['Radical_split'].head(50)
# Out:
# 0          [一]
# 1          [丨]
# 2          [丶]
# 3          [丿]
# 4     [乙, (乚)]
# 5          [亅]
# 6          [二]
# 7          [亠]
# 8          [人]
# 9          [亻]
# 10         [𠆢]
# 11         [入]
# 12         [八]
# 13         [ハ]
# 14         [儿]
# 15         [丷]
# 16         [冫]
# 17         [凵]
# 18         [匚]
# 19         [冂]
# 20         [冖]
# 21         [几]
# 22         [九]
# 23         [力]
# 24         [刀]
# 25         [刂]
# 26         [乃]
# 27         [勹]
# 28         [⺈]
# 29         [マ]
# 30         [匕]
# 31         [十]
# 32         [卜]
# 33         [又]
# 34         [厶]
# 35    [卩, (㔾)]
# 36         [厂]
# 37         [广]
# 38         [口]
# 39         [囗]
# 40         [土]
# 41         [士]
# 42         [夂]
# 43         [夕]
# 44         [尢]
# 45         [大]
# 46         [女]
# 47         [子]
# 48         [宀]
# 49         [寸]
# Name: Radical_split, dtype: object

# %%
#spliting nested kanji tp keep only 1st kanji on each row
df_meaning_tidy['Radical'] = df_meaning_tidy['Radical'].str.replace(' ', ',')

df_meaning_tidy['Radical_split'] = df_meaning_tidy['Radical'].str.split(",").apply(lambda x : x[0])

df_meaning_tidy['Radical_split']
# Out:
# 0      一
# 1      丨
# 2      丶
# 3      丿
# 4      乙
#       ..
# 188    品
# 189    馬
# 190    高
# 191    啇
# 192    無
# Name: Radical_split, Length: 193, dtype: object

# %%
df_radicals['Radical (variants)'] = df_radicals['Radical (variants)'].str.replace(' ', ',')

df_radicals['Radical (variants)_split'] = df_radicals['Radical (variants)'].str.split(",").apply(lambda x : x[0])

df_radicals['Radical (variants)_split']
# Out:
# 0      一
# 1      丨
# 2      丶
# 3      丿
# 4      乙
#       ..
# 209    齊
# 210    歯
# 211    竜
# 212    亀
# 213    龠
# Name: Radical (variants)_split, Length: 214, dtype: object

# %%
df_radicals['Radical (variants)_split'].tail(50)
# Out:
# 164    釆
# 165    里
# 166    金
# 167    長
# 168    門
# 169    阜
# 170    隶
# 171    隹
# 172    雨
# 173    青
# 174    非
# 175    面
# 176    革
# 177    韋
# 178    韭
# 179    音
# 180    頁
# 181    風
# 182    飛
# 183    食
# 184    首
# 185    香
# 186    馬
# 187    骨
# 188    高
# 189    髟
# 190    鬥
# 191    鬯
# 192    鬲
# 193    鬼
# 194    魚
# 195    鳥
# 196    鹵
# 197    鹿
# 198    麦
# 199    麻
# 200    黄
# 201    黍
# 202    黒
# 203    黹
# 204    黽
# 205    鼎
# 206    鼓
# 207    鼠
# 208    鼻
# 209    齊
# 210    歯
# 211    竜
# 212    亀
# 213    龠
# Name: Radical (variants)_split, dtype: object

# %%
df_diff = df_radicals.loc[~(df_radicals["Radical (variants)_split"].isin(df_meaning_tidy["Radical_split"]))]
df_diff
# Out:
#      No. Radical (variants)  Stroke count  \
# 34    35                  夊             3
# 44    45                  屮             3
# 46    47            巛,(川,巜)             3
# 64    65                  支             4
# 70    71              无,(旡)             4
# ..   ...                ...           ...
# 209  210                  齊            14
# 210  211              歯,(齒)            12
# 211  212              竜,(龍)            10
# 212  213              亀,(龜)            11
# 213  214                  龠            17
#
#                      Meaning and reading  Frequency  Jōyō freq Examples Group  \
# 34   winter variant (すいにょう, suinyou, 夊繞)        NaN        NaN      NaN   NaN
# 44                    sprout (てつ, tetsu)       38.0        NaN        屯   NaN
# 46                      river (かわ, kawa)       26.0        NaN      川州巡   NaN
# 64             branch (しにょう, shinyō, 支繞)       26.0        NaN       攱攲   NaN
# 70                have not (むにょう, munyō)       12.0        NaN  无 旡 既 旣   NaN
# ..                                   ...        ...        ...      ...   ...
# 209         even, uniformly (せい, sei, 斉)       18.0        NaN    齋 齏 齏   NaN
# 210                 tooth, molar (は, ha)      162.0        NaN    齡 齠 齗   NaN
# 211                    dragon (りゅう, ryū)       14.0        NaN      龖 龘   NaN
# 212          turtle, tortoise (かめ, kame)       24.0        NaN        龝   NaN
# 213                     flute (やく, yaku)       19.0        NaN        龣   NaN
#
#     Radical (variants)_split
# 34                         夊
# 44                         屮
# 46                         巛
# 64                         支
# 70                         无
# ..                       ...
# 209                        齊
# 210                        歯
# 211                        竜
# 212                        亀
# 213                        龠
#
# [63 rows x 9 columns]

# %%
df_diff2 = df_meaning_tidy.loc[~(df_meaning_tidy["Radical_split"].isin(df_radicals["Radical (variants)_split"]))]
df_diff2
# Out:
#     Radical  Stroke count Hiragana-Romaji                        Meaning  \
# 9         亻             2             NaN                  human, person
# 10        𠆢             2             NaN          person (人); (入; roof)
# 13        ハ             2             NaN                    animal legs
# 15        丷             2             NaN            grass, plant; horns
# 22        九             2         きゅう-kyū                           nine
# 25        刂             2             NaN                   knife, sword
# 26        乃             2            の-no                            NaN
# 28        ⺈             2             NaN                   knife, sword
# 29        マ             2           ま-ma.                     Katakana マ
# 51    ⺌,(⺍)             3             NaN           small, insignificant
# 55        川             3         かわ-kawa                          river
# 64        也             3             NaN                            NaN
# 70        氵             3             NaN                          water
# 71    丬,(爿)             3             NaN                     split wood
# 72        犭             3             NaN                            dog
# 73        扌             3             NaN                           hand
# 75       ⻖←             3             NaN                 mound (阝-left)
# 76       →⻏             3             NaN                 town (阝-right)
# 77        忄             3             NaN                          heart
# 101       灬             4             NaN                           fire
# 102   ⺤,(爪)             4        つめ-tsume              claw, nail, talon
# 107       礻             4             NaN                 altar, display
# 109       勿             4             NaN                         do not
# 110       五             4            ご-go                           five
# 111       巴             4             NaN  cylinder with a trailing tail
# 112       元             4         もと-moto                   base, origin
# 113       井             4          せい-sei                           well
# 114       予             4            よ-yo         beforehand, previously
# 115       屯             4          トン-ton                            NaN
# 133       母             5         はは-haha                         mother
# 134       衤             5             NaN                        clothes
# 136       世             5            よ-yo     society, world; generation
# 137       ⺻             5             NaN                          brush
# 138       冊             5        さつ-satsu               (counting) books
# 140       ⺮             6         たけ-take                         bamboo
# 157   覀,(襾)             6        にし-nishi                           west
# 181       岡             8          おか-oka                           hill
# 182       免             8         めん-menn                      dismissal
# 183       斉             8          せい-sei             Chinese Qi kingdom
# 188       品             9          ひん-hin                           item
# 191       啇            11             NaN                     base, stem
# 192       無            12            む-mu                        nothing
#
#     Position                                           Examples Radical_split  \
# 9          ◧                        仏 化 付 代 他 仕 休 位 作 体 住 何 花 信             亻
# 10         ⊤                                        介 今 合 全 会 谷             𠆢
# 13         ⊥                六 穴 呉 兵 貝 洪 唄 冥 浜 財 員 棋 貿 貸 買 賛 質 興             ハ
# 15         ⊤                                      平 半 羊 岡 前 首 南             丷
# 22       NaN                                                NaN             九
# 25         ◨                                                NaN             刂
# 26         ⊥                                         秀 透 携 誘 /及             乃
# 28         ⊤                危 争 色 角 免 浄 急 負 陥 逸 亀 喚 換 象 像 静 衡 艶             ⺈
# 29         ⊤                               勇 通 湧 痛 踊 疑 凝 擬 /予 矛             マ
# 51       NaN                                当 光 鎖 巣 桜 獣 単 脳 悩 厳             ⺌
# 55       NaN                                              川 州 巡             川
# 64         ◨                                            地 池 他 施             也
# 70         ◧                                      泳 決 治 海 演 漢 瀬             氵
# 71         ◧                                  北 壮 状 荘 背 将 装 寝 奨             丬
# 72         ◧                                              犯 狂 狙             犭
# 73         ◧                                      持 掛 打 批 技 抱 押             扌
# 75         ◧                                          阪 防 阻 院 陳            ⻖←
# 76         ◨                                        那 邦 郎 部 郭 都            →⻏
# 77         ◧  忙 快 怪 怖 性 恒 恨 悔 悟 悩 悦 惨 悼 惧 惜 情 愉 惰 慌 慄 慨 慎 憎 慢 慣             忄
# 101      NaN                                              焦 然 煮             灬
# 102      NaN  爪 妥 采 乳 受 浮 将 渓 淫 彩 授 採 菜 援 揺 媛 奨 暖 愛 稲 緩 謡 穏 曖 爵             ⺤
# 107      NaN                                          礼 社 神 視 福             礻
# 109      NaN                                                NaN             勿
# 110      NaN                                                  五             五
# 111      NaN                                              色 把 肥             巴
# 112      NaN                                                NaN             元
# 113      NaN                                                NaN             井
# 114      NaN                                         予 序 野 預 /矛             予
# 115      NaN                                            屯 純 鈍 頓             屯
# 133      NaN                                                  母             母
# 134      NaN                                              初 被 複             衤
# 136      NaN                                                NaN             世
# 137      NaN                                    津 律 建 書 庸 健 筆 鍵             ⺻
# 138      NaN                                    冊 柵 倫 偏 遍 論 編 輪             冊
# 140      NaN                              竹 第 筆 竿 算 答 管 筋 等 笑 箸             ⺮
# 157      NaN                            西 価 要 票 煙 腰 慄 漂 遷 標 覆 覇             覀
# 181      NaN                                            岡 剛 綱 鋼             岡
# 182      NaN                                            免 勉 逸 晩             免
# 183      NaN                                            斉 剤 斎 済             斉
# 188      NaN                                                NaN             品
# 191      NaN                                          嫡 滴 摘 適 敵             啇
# 192      NaN                                                無 舞             無
#
#     Radical_split2
# 9                亻
# 10               𠆢
# 13               ハ
# 15               丷
# 22               九
# 25               刂
# 26               乃
# 28               ⺈
# 29               マ
# 51               ⺌
# 55               川
# 64               也
# 70               氵
# 71               丬
# 72               犭
# 73               扌
# 75              ⻖←
# 76              →⻏
# 77               忄
# 101              灬
# 102              ⺤
# 107              礻
# 109              勿
# 110              五
# 111              巴
# 112              元
# 113              井
# 114              予
# 115              屯
# 133              母
# 134              衤
# 136              世
# 137              ⺻
# 138              冊
# 140              ⺮
# 157              覀
# 181              岡
# 182              免
# 183              斉
# 188              品
# 191              啇
# 192              無

# %%
df_diff2.shape
# Out:
# (42, 8)

# %%
#there are differences of complicated symbols between 2 dfs i.e. difference between classical Chinese & Japanese Kanji

#need to fetch other Kanji radical df

# %%
df_diff = df_radicals.merge(df_meaning_tidy,
                 how='outer',
                 left_on="Radical (variants)_split",
                 right_on="Radical_split")
df_diff
# Out:
#      No. Radical (variants)  Stroke count_x  \
# 0    1.0                  一             1.0
# 1    2.0                  丨             1.0
# 2    3.0                  丶             1.0
# 3    4.0                  丿             1.0
# 4    5.0              乙,(乚)             1.0
# ..   ...                ...             ...
# 251  NaN                NaN             NaN
# 252  NaN                NaN             NaN
# 253  NaN                NaN             NaN
# 254  NaN                NaN             NaN
# 255  NaN                NaN             NaN
#
#                          Meaning and reading  Frequency  Jōyō freq Examples_x  \
# 0                          one (いち, ichi, 一)       42.0       50.0     七三丈不丘世
# 1                    line, stick (ぼう, bō, 棒)       21.0        NaN          中
# 2                           dot (てん, ten, 点)       10.0        NaN         丸主
# 3    bend, possessive particle no (の, no, ノ)       33.0        NaN        久之乎
# 4               second, latter (おつ, otsu, 乙)       42.0        NaN         九也
# ..                                       ...        ...        ...        ...
# 251                                      NaN        NaN        NaN        NaN
# 252                                      NaN        NaN        NaN        NaN
# 253                                      NaN        NaN        NaN        NaN
# 254                                      NaN        NaN        NaN        NaN
# 255                                      NaN        NaN        NaN        NaN
#
#     Group Radical (variants)_split Radical  Stroke count_y Hiragana-Romaji  \
# 0     NaN                        一       一             1.0         いち-ichi
# 1     NaN                        丨       丨             1.0             NaN
# 2     NaN                        丶       丶             1.0          てん-ten
# 3     NaN                        丿       丿             1.0             NaN
# 4     NaN                        乙   乙,(乚)             1.0         おつ-otsu
# ..    ...                      ...     ...             ...             ...
# 251   NaN                      NaN       免             8.0         めん-menn
# 252   NaN                      NaN       斉             8.0          せい-sei
# 253   NaN                      NaN       品             9.0          ひん-hin
# 254   NaN                      NaN       啇            11.0             NaN
# 255   NaN                      NaN       無            12.0            む-mu
#
#                 Meaning Position             Examples_y Radical_split  \
# 0                   one      NaN                  一 戸 旦             一
# 1                  line      NaN              巾 引 中 甲 旧             丨
# 2                   dot      NaN          刃 凡 丸 丹 太 犬 丼             丶
# 3                  bend      NaN            丈 久 才 万 丹 少             丿
# 4        second, latter      NaN  乙 乞 乏 孔 屯 札 礼 宅 乱 枕 乳             乙
# ..                  ...      ...                    ...           ...
# 251           dismissal      NaN                免 勉 逸 晩             免
# 252  Chinese Qi kingdom      NaN                斉 剤 斎 済             斉
# 253                item      NaN                    NaN             品
# 254          base, stem      NaN              嫡 滴 摘 適 敵             啇
# 255             nothing      NaN                    無 舞             無
#
#     Radical_split2
# 0                一
# 1                丨
# 2                丶
# 3                丿
# 4                乙
# ..             ...
# 251              免
# 252              斉
# 253              品
# 254              啇
# 255              無
#
# [256 rows x 17 columns]

# %%
df_meaning_tidy['Radical_split'].tail(50)
# Out:
# 143    缶
# 144    羊
# 145    羽
# 146    耳
# 147    自
# 148    至
# 149    舌
# 150    舟
# 151    艮
# 152    虍
# 153    虫
# 154    血
# 155    行
# 156    衣
# 157    覀
# 158    臣
# 159    見
# 160    角
# 161    言
# 162    谷
# 163    豆
# 164    豕
# 165    貝
# 166    足
# 167    身
# 168    車
# 169    辛
# 170    辰
# 171    酉
# 172    里
# 173    赤
# 174    走
# 175    金
# 176    長
# 177    門
# 178    隹
# 179    雨
# 180    青
# 181    岡
# 182    免
# 183    斉
# 184    音
# 185    頁
# 186    食
# 187    首
# 188    品
# 189    馬
# 190    高
# 191    啇
# 192    無
# Name: Radical_split, dtype: object

# %%
df_radicals.columns

df_radicals['Radical (variants)'].fillna('', inplace=True)

df_radicals['Radical (variants)_split'] = df_radicals['Radical (variants)'].str.split(",", expand=True)


#df_meaning_tidy['Radical_split'] = df_meaning_tidy['Radical_split'].apply(lambda x : list(x))
#df_meaning_tidy['Radical_split'] = df_meaning_tidy['Radical_split'].

df_radicals.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Radical (variants)_split'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3745         try:
# -> 3746             loc = self._info_axis.get_loc(key)
#    3747         except KeyError:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#
# KeyError: 'Radical (variants)_split'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-326db960a585> in <module>
#       3 df_radicals['Radical (variants)'].fillna('', inplace=True)
#       4
# ----> 5 df_radicals['Radical (variants)_split'] = df_radicals['Radical (variants)'].str.split(",", expand=True)
#       6
#       7
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3597             self._setitem_array(key, value)
#    3598         elif isinstance(value, DataFrame):
# -> 3599             self._set_item_frame_value(key, value)
#    3600         elif is_list_like(value) and 1 < len(
#    3601             self.columns.get_indexer_for([key])
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3735         # now align rows
#    3736         arraylike = _reindex_for_setitem(value, self.index)
# -> 3737         self._set_item_mgr(key, arraylike)
#    3738
#    3739     def _iset_item_mgr(self, loc: int | slice | np.ndarray, value) -> None:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3747         except KeyError:
#    3748             # This item wasn't present, just insert at end
# -> 3749             self._mgr.insert(len(self._info_axis), key, value)
#    3750         else:
#    3751             self._iset_item_mgr(loc, value)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value)
#    1160             value = ensure_block_shape(value, ndim=self.ndim)
#    1161
# -> 1162         block = new_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1163
#    1164         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\blocks.py in new_block(values, placement, ndim, klass)
#    1930
#    1931     values, _ = extract_pandas_array(values, None, ndim)
# -> 1932     check_ndim(values, placement, ndim)
#    1933
#    1934     if klass is None:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\blocks.py in check_ndim(values, placement, ndim)
#    1972             )
#    1973         if len(placement) != len(values):
# -> 1974             raise ValueError(
#    1975                 f"Wrong number of items passed {len(values)}, "
#    1976                 f"placement implies {len(placement)}"
#
# ValueError: Wrong number of items passed 4, placement implies 1

# %%
#list of not official not recognized by Kangxi
df_unofficial = pd.read_html('https://en.wikipedia.org/wiki/List_of_kanji_radicals_by_stroke_count')[1]

df_unofficial
